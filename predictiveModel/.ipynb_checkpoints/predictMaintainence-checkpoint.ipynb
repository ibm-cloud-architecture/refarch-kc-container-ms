# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn import metrics

# %%
data = pd.read_csv('../data/container_matrix_door_open.csv', delimiter=",")
data.head()
# Out:
#              Timestamp    ID  Temperature(celsius)  \
# 0  2019-03-14 T18:07 Z  1992              4.234727
# 1  2019-03-14 T18:22 Z  1992              3.537420
# 2  2019-03-14 T18:37 Z  1992              3.490384
# 3  2019-03-14 T18:52 Z  1992              3.334489
# 4  2019-03-14 T19:07 Z  1992              4.151678
#
#    Target_Temperature(celsius)       Amp  CumulativePowerConsumption  \
# 0                          4.4  2.220938                   10.207381
# 1                          4.4  2.576245                    7.929235
# 2                          4.4  0.888891                    8.273427
# 3                          4.4  4.495335                    7.285007
# 4                          4.4  2.147343                   10.018525
#
#    ContentType   Humidity        CO2  Door_Open  Maintainence_Required  \
# 0            5  10.125844   8.683768          1                      0
# 1            2  14.530501  10.904526          1                      0
# 2            1  15.635786   9.598969          1                      0
# 3            3  18.055472   9.563723          1                      0
# 4            3   9.978596  20.424016          1                      0
#
#    Defrost_Cycle
# 0              6
# 1              6
# 2              6
# 3              6
# 4              6

# %%
# create a Python list of feature names
feature_cols = ['Temperature(celsius)', 'Door_Open','Target_Temperature(celsius)','Amp','ContentType','CumulativePowerConsumption'
                          ,'Humidity','CO2','Defrost_Cycle']

# use the list to select a subset of the original DataFrame
X = data[feature_cols]
y = data['Maintainence_Required']

# print the first 5 rows
X.head()
# Out:
#    Temperature(celsius)  Door_Open  Target_Temperature(celsius)       Amp  \
# 0              4.234727          1                          4.4  2.220938
# 1              3.537420          1                          4.4  2.576245
# 2              3.490384          1                          4.4  0.888891
# 3              3.334489          1                          4.4  4.495335
# 4              4.151678          1                          4.4  2.147343
#
#    ContentType  CumulativePowerConsumption   Humidity        CO2  \
# 0            5                   10.207381  10.125844   8.683768
# 1            2                    7.929235  14.530501  10.904526
# 2            1                    8.273427  15.635786   9.598969
# 3            3                    7.285007  18.055472   9.563723
# 4            3                   10.018525   9.978596  20.424016
#
#    Defrost_Cycle
# 0              6
# 1              6
# 2              6
# 3              6
# 4              6

# %%
import pickle

#loading a model from a file called model.pkl
model = pickle.load(open("model.pkl","r"))

# %%
# make predictions on the input set
y_pred = model.predict(X)
#y_pred
#y_pred.shape
print(np.sqrt(metrics.mean_squared_error(y, y_pred)))
# Out:
# 0.01737186554184564
