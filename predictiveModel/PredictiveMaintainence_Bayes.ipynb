# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

# %%
data = pd.read_csv('../data/container_matrix_test.csv', delimiter=",")
data.head()
# Out:
#              Timestamp    ID  Temperature(celsius)  \
# 0  2019-03-21 T14:58 Z  1612              6.756764
# 1  2019-03-21 T14:58 Z  1612             13.277507
# 2  2019-03-21 T15:13 Z  1612              7.000711
# 3  2019-03-21 T15:13 Z  1612              9.085153
# 4  2019-03-21 T15:28 Z  1612              3.013623
#
#    Target_Temperature(celsius)       Amp  CumulativePowerConsumption  \
# 0                          4.4  1.612088                   10.075187
# 1                          4.4  2.044077                    6.676213
# 2                          4.4  2.679326                   10.890773
# 3                          4.4  0.963377                    9.960045
# 4                          4.4  2.699073                    8.154434
#
#    ContentType   Humidity        CO2  Door_Open  Maintainence_Required  \
# 0            3   4.244906  10.214897          0                      1
# 1            2  10.957086   9.531931          0                      1
# 2            3   7.402391   7.324585          0                      1
# 3            5   6.699857  12.477479          0                      1
# 4            5   4.837972  14.225478          0                      1
#
#    Defrost_Cycle
# 0              6
# 1              6
# 2              6
# 3              6
# 4              6

# %%
# create a Python list of feature names
feature_cols = ['Temperature(celsius)', 'Door_Open','Target_Temperature(celsius)','Amp','ContentType','CumulativePowerConsumption'
                          ,'Humidity','CO2','Defrost_Cycle']

# use the list to select a subset of the original DataFrame
X = data[feature_cols]
y = data['Maintainence_Required']

# print the first 5 rows
X.head()
# Out:
#    Temperature(celsius)  Door_Open  Target_Temperature(celsius)       Amp  \
# 0              6.756764          0                          4.4  1.612088
# 1             13.277507          0                          4.4  2.044077
# 2              7.000711          0                          4.4  2.679326
# 3              9.085153          0                          4.4  0.963377
# 4              3.013623          0                          4.4  2.699073
#
#    ContentType  CumulativePowerConsumption   Humidity        CO2  \
# 0            3                   10.075187   4.244906  10.214897
# 1            2                    6.676213  10.957086   9.531931
# 2            3                   10.890773   7.402391   7.324585
# 3            5                    9.960045   6.699857  12.477479
# 4            5                    8.154434   4.837972  14.225478
#
#    Defrost_Cycle
# 0              6
# 1              6
# 2              6
# 3              6
# 4              6

# %%
import pickle

#loading a model from a file called model.pkl
model = pickle.load(open("model_bays.pkl","r"))

# %%
# make predictions on the input set
y_pred = model.predict(X)
print y_pred
#y_pred.shape
print(np.sqrt(metrics.mean_squared_error(y, y_pred)))
# Out:
# [1 1 1 ... 1 1 1]
# 0.022360679774997897
